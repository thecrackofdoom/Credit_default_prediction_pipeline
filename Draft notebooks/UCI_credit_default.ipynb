# %%
# !pip install -q kaggle
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !kaggle datasets download uciml/default-of-credit-card-clients-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/uciml/default-of-credit-card-clients-dataset
# License(s): CC0-1.0
# default-of-credit-card-clients-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import pandas as pd
df = pd.read_csv("UCI_Credit_Card.csv")
df.dropna()
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df["EDUCATION"].value_counts()
# Out:
# EDUCATION
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: count, dtype: int64

# %%
df.hist(bins = 30, figsize=(30,30))
# Out:
# array([[<Axes: title={'center': 'ID'}>,
#         <Axes: title={'center': 'LIMIT_BAL'}>,
#         <Axes: title={'center': 'SEX'}>,
#         <Axes: title={'center': 'EDUCATION'}>,
#         <Axes: title={'center': 'MARRIAGE'}>],
#        [<Axes: title={'center': 'AGE'}>,
#         <Axes: title={'center': 'PAY_0'}>,
#         <Axes: title={'center': 'PAY_2'}>,
#         <Axes: title={'center': 'PAY_3'}>,
#         <Axes: title={'center': 'PAY_4'}>],
#        [<Axes: title={'center': 'PAY_5'}>,
#         <Axes: title={'center': 'PAY_6'}>,
#         <Axes: title={'center': 'BILL_AMT1'}>,
#         <Axes: title={'center': 'BILL_AMT2'}>,
#         <Axes: title={'center': 'BILL_AMT3'}>],
#        [<Axes: title={'center': 'BILL_AMT4'}>,
#         <Axes: title={'center': 'BILL_AMT5'}>,
#         <Axes: title={'center': 'BILL_AMT6'}>,
#         <Axes: title={'center': 'PAY_AMT1'}>,
#         <Axes: title={'center': 'PAY_AMT2'}>],
#        [<Axes: title={'center': 'PAY_AMT3'}>,
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df = df.rename(columns={'default.payment.next.month': 'de_pay',
                        'PAY_0': 'PAY_1'})
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.de_pay.sum() / len(df.de_pay)
# Out:
# np.float64(0.2212)

# %%
fil = (df.EDUCATION == 5) | (df.EDUCATION == 6) | (df.EDUCATION == 0)
df.loc[fil, 'EDUCATION'] = 4
df.EDUCATION.value_counts()
# Out:
# EDUCATION
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: count, dtype: int64

# %%
df.loc[df.MARRIAGE == 0, 'MARRIAGE'] = 3
df['MARRIAGE'].value_counts()
# Out:
# MARRIAGE
# 2    15964
# 1    13659
# 3      377
# Name: count, dtype: int64

# %%
corr = df.corr()
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c5cee_row0_col0, #T_c5cee_row1_col1, #T_c5cee_row2_col2, #T_c5cee_row3_col3, #T_c5cee_row4_col4, #T_c5cee_row5_col5, #T_c5cee_row6_col6, #T_c5cee_row7_col7, #T_c5cee_row8_col8, #T_c5cee_row9_col9, #T_c5cee_row10_col10, #T_c5cee_row11_col11, #T_c5cee_row12_col12, #T_c5cee_row13_col13, #T_c5cee_row14_col14, #T_c5cee_row15_col15, #T_c5cee_row16_col16, #T_c5cee_row17_col17, #T_c5cee_row18_col18, #T_c5cee_row19_col19, #T_c5cee_row20_col20, #T_c5cee_row21_col21, #T_c5cee_row22_col22, #T_c5cee_row23_col23, #T_c5cee_row24_col24 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c5cee_row0_col1, #T_c5cee_row2_col1, #T_c5cee_row4_col7, #T_c5cee_row4_col8, #T_c5cee_row8_col14, #T_c5cee_row8_col15, #T_c5cee_row8_col16, #T_c5cee_row9_col13, #T_c5cee_row18_col21, #T_c5cee_row23_col18 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_c5cee_row0_col2, #T_c5cee_row2_col24, #T_c5cee_row5_col18 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(30,14))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f",)
plt.show()

# %%
fil = (df.PAY_1 == -2) | (df.PAY_1 == -1) | (df.PAY_1 == 0)
df.loc[fil, 'PAY_1'] = 0
fil = (df.PAY_2 == -2) | (df.PAY_2 == -1) | (df.PAY_2 == 0)
df.loc[fil, 'PAY_2'] = 0
fil = (df.PAY_3 == -2) | (df.PAY_3 == -1) | (df.PAY_3 == 0)
df.loc[fil, 'PAY_3'] = 0
fil = (df.PAY_4 == -2) | (df.PAY_4 == -1) | (df.PAY_4 == 0)
df.loc[fil, 'PAY_4'] = 0
fil = (df.PAY_5 == -2) | (df.PAY_5 == -1) | (df.PAY_5 == 0)
df.loc[fil, 'PAY_5'] = 0
fil = (df.PAY_6 == -2) | (df.PAY_6 == -1) | (df.PAY_6 == 0)
df.loc[fil, 'PAY_6'] = 0

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2      0      0
# 1   2   120000.0    2          2         2   26      0      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57      0      0      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  de_pay
# 0       0.0       0.0       0.0       1
# ...

# %%
df['PAY_1'].hist()
# Out:
# <Axes: >

# %%
# %pip install -q plotly
# %pip install -q imblearn
# %pip install -q xgboost
# %pip install -q scikit-learn
# %pip install -q scipy
# %pip install -q seaborn
# %pip install -q matplotlib
from plotly.subplots import make_subplots
import plotly.io as pio
pio.templates.default = "plotly_dark"

from sklearn.linear_model import LogisticRegression
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import RFE,SelectFromModel
from sklearn.model_selection import KFold,GridSearchCV,RandomizedSearchCV,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import GaussianNB
from scipy.stats import randint as sp_randint
from sklearn.ensemble import RandomForestClassifier ,ExtraTreesClassifier, AdaBoostClassifier,GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report,confusion_matrix,f1_score,roc_auc_score,roc_curve,accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import plotly.figure_factory as ff

X = df.drop(['ID', 'de_pay'], axis=1)
y = df['de_pay']
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y, random_state=100)

# %%
import numpy as np
param_lr = {'max_iter': 1000,
            'solver':'lbfgs',
            'C': 1}

LR = LogisticRegression(**param_lr, random_state=100)
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
print('Accuracy:', accuracy_score(y_pred,y_test))
LR_report = classification_report(y_test, y_pred, output_dict=True)

cv_scores = cross_val_score(LR, X, y, cv=5)
print()
print(classification_report(y_test, y_pred))
print()
print("Average 5-Fold CV Score: {}".format(round(np.mean(cv_scores),4)),
      ", Standard deviation: {}".format(round(np.std(cv_scores),4)))
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.8056666666666666
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred)
CMdist = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Does not Default','Default'])
CMdist.plot()
plt.show()

# %%
LR_report
# Out:
# {'0': {'precision': 0.8212017586712261,
#   'recall': 0.9593379940077044,
#   'f1-score': 0.8849114956899388,
#   'support': 7009.0},
#  '1': {'precision': 0.6490147783251231,
#   'recall': 0.2646911099949774,
#   'f1-score': 0.37602568676418124,
#   'support': 1991.0},
#  'accuracy': 0.8056666666666666,
#  'macro avg': {'precision': 0.7351082684981747,
#   'recall': 0.6120145520013409,
#   'f1-score': 0.63046859122706,
#   'support': 9000.0},
#  'weighted avg': {'precision': 0.7831101722413272,
#   'recall': 0.8056666666666666,
#   'f1-score': 0.7723346461820294,
#   'support': 9000.0}}

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.842267      1.557267
# std     8660.398374   129747.661567      0.489129      0.744494      0.521405
# min        1.000000    10000.000000      1.000000      1.000000      1.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      4.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500      0.356767      0.320033      0.304067      0.258767
# ...

# %%
df.columns
df[['SEX','EDUCATION','MARRIAGE']] = df[['SEX','EDUCATION','MARRIAGE']].astype('object')
df = pd.get_dummies(df)
df.head()
# Out:
#    ID  LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
# 0   1    20000.0   24      2      2      0      0      0      0     3913.0
# 1   2   120000.0   26      0      2      0      0      0      2     2682.0
# 2   3    90000.0   34      0      0      0      0      0      0    29239.0
# 3   4    50000.0   37      0      0      0      0      0      0    46990.0
# 4   5    50000.0   57      0      0      0      0      0      0     8617.0
#
#    ...  de_pay  SEX_1  SEX_2  EDUCATION_1  EDUCATION_2  EDUCATION_3  \
# 0  ...       1  False   True        False         True        False
# 1  ...       1  False   True        False         True        False
# 2  ...       0  False   True        False         True        False
# 3  ...       0  False   True        False         True        False
# 4  ...       0   True  False        False         True        False
#
#    EDUCATION_4  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3
# 0        False        True       False       False
# ...

# %%
X = df.drop(['ID','de_pay'], axis = 1)
y = df['de_pay']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, stratify=y, random_state=100)

df_train = X_train.join(y_train)
df_train.head()
# Out:
#        LIMIT_BAL  AGE  PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  \
# 18696   200000.0   28      0      0      0      0      0      0    18134.0
# 26263    90000.0   32      0      0      0      0      0      0    88729.0
# 15928   210000.0   32      0      0      0      0      0      0   189307.0
# 8580    230000.0   32      0      0      0      0      0      0   195409.0
# 15194    50000.0   25      0      0      0      0      0      0    16092.0
#
#        BILL_AMT2  ...  SEX_1  SEX_2  EDUCATION_1  EDUCATION_2  EDUCATION_3  \
# 18696    18410.0  ...  False   True         True        False        False
# 26263    88533.0  ...  False   True        False         True        False
# 15928   194602.0  ...  False   True        False         True        False
# 8580    203432.0  ...  False   True         True        False        False
# 15194    12352.0  ...  False   True        False         True        False
#
#        EDUCATION_4  MARRIAGE_1  MARRIAGE_2  MARRIAGE_3  de_pay
# ...

# %%
df_majority = df_train[df_train.de_pay == 0]
df_minority = df_train[df_train.de_pay == 1]

df_minority_upsampled = resample(df_minority,
                                 replace=True,     # sample with replacement
                                 n_samples = 16355,    # to match majority class
                                 random_state= 42) # reproducible results
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
# Display new class counts
df_upsampled.de_pay.value_counts()
# Out:
# de_pay
# 0    16355
# 1    16355
# Name: count, dtype: int64

# %%
sm = SMOTE(random_state=100)
X_SMOTE, y_SMOTE = sm.fit_resample(X_train, y_train)
print(len(y_SMOTE))
print(y_SMOTE.sum())
# Out:
# 32710
# 16355

# %%
XGB_reports = []
XGB_models = []

def model_eval(algo, Xtrain,ytrain,Xtest,ytest):
    from sklearn.metrics import confusion_matrix,accuracy_score,roc_auc_score,roc_curve,classification_report

    algo.fit(Xtrain,ytrain)
    y_pred = algo.predict(Xtrain)
    y_train_prob = algo.predict_proba(Xtrain)[:,1]

    #print('confusion matrix-train\n',confusion_matrix(ytrain,y_pred))
    print('Overall Train Accuracy',accuracy_score(ytrain,y_pred))
    print('Train AUC Score',roc_auc_score(ytrain,y_train_prob))

    y_test_pred = algo.predict(Xtest)
    y_test_prob = algo.predict_proba(Xtest)[:,1]


    #print('confusion matrix-test\n',confusion_matrix(ytest,y_test_pred))
    print('Overall Test Accuracy',accuracy_score(ytest,y_test_pred))
    print('Test AUC Score',roc_auc_score(ytest,y_test_prob))
    print('Classification Report of Test\n',  classification_report(ytest, y_test_pred))


    kf = KFold(n_splits = 5,shuffle = True,random_state = 42)
    score=[]
    for train_idx,test_idx in kf.split(Xtrain,ytrain):
        xtrain_k,xtest_k = Xtrain.iloc[train_idx,:],Xtrain.iloc[test_idx,:]
        ytrain_k,ytest_k = ytrain.iloc[train_idx],ytrain.iloc[test_idx]
        algo.fit(xtrain_k,ytrain_k)
        y_pred_k = algo.predict(xtest_k)
        roc = roc_auc_score(ytest_k,y_pred_k)
        score.append(roc)
    print('K-Fold scores: %0.03f (+/- %0.5f)' % (np.mean(score),np.var(score,ddof=1)))

    f,ax =  plt.subplots(1,2,figsize=(14,6))
    #plt.figure(figsize=(6,4))
    ConfMatrix = confusion_matrix(ytest,y_test_pred)
    sns.heatmap(ConfMatrix,annot=True, cmap='YlGnBu', fmt="d",
            xticklabels = ['Non-default', 'Default'],
            yticklabels = ['Non-default', 'Default'],linewidths=.5,ax = ax[0])
    ax[0].set_ylabel('True label')
    ax[0].set_xlabel('Predicted label')
    ax[0].set_title('Confusion Matrix')

    global fpr,tpr,thresholds
    fpr,tpr,thresholds = roc_curve(ytest,y_test_prob)
    ax[1].plot(fpr,tpr,color = 'r')
    ax[1].plot(fpr,fpr,color = 'green')
    ax[1].set_ylabel('TPR')
    ax[1].set_xlabel('FPR')
    ax[1].set_title('ROC Curve')
    plt.show()
    
    XGB_reports.append(classification_report(ytest, y_test_pred, output_dict=True))
    XGB_models.append(algo)

# %%
xtrain_data = [X_train,df_upsampled.drop('de_pay',axis = 1),X_SMOTE]
ytrain_data = [y_train,df_upsampled['de_pay'],y_SMOTE]
name = ['Normal Sampling' , 'Over Sampling' , 'SMOTE']

'''for i,j,k in zip(xtrain_data,ytrain_data,name):
    global best_xgb
    best_xgb =[]
    print('Data is ',k)  # Instantiate a XGBoost classifier
    xgb= XGBClassifier()

    param_grid = {"learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30] ,
                  "max_depth"        : [3, 4, 5, 6, 8, 10, 12, 15],
                 "min_child_weight" : [1, 3, 5, 7],
                 "gamma"            : [0.0, 0.1, 0.2 , 0.3, 0.4],
                 "colsample_bytree" : [0.3, 0.4, 0.5 , 0.7],
                 'scale_pos_weight': [1, 3, 5, 7]}

    #Building a 5 fold CV GridSearchCV object
    xgb_RS = RandomizedSearchCV(xgb, param_grid ,cv = 5, scoring = 'roc_auc',n_iter = 200,n_jobs = -1)

    #Fitting the grid to the training data
    xgb_RS.fit(i,j)
    best_xgb.append(xgb_RS.best_params_)
    print("Tuned XG Boost Parameters: {}".format(xgb_RS.best_params_), "for",k)
    print("_" * 100)'''
# Out:
# 'for i,j,k in zip(xtrain_data,ytrain_data,name):\n    global best_xgb\n    best_xgb =[]\n    print(\'Data is \',k)  # Instantiate a XGBoost classifier\n    xgb= XGBClassifier()\n\n    param_grid = {"learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30] ,\n                  "max_depth"        : [3, 4, 5, 6, 8, 10, 12, 15],\n                 "min_child_weight" : [1, 3, 5, 7],\n                 "gamma"            : [0.0, 0.1, 0.2 , 0.3, 0.4],\n                 "colsample_bytree" : [0.3, 0.4, 0.5 , 0.7],\n                 \'scale_pos_weight\': [1, 3, 5, 7]}\n\n    #Building a 5 fold CV GridSearchCV object\n    xgb_RS = RandomizedSearchCV(xgb, param_grid ,cv = 5, scoring = \'roc_auc\',n_iter = 200,n_jobs = -1)\n\n    #Fitting the grid to the training data\n    xgb_RS.fit(i,j)\n    best_xgb.append(xgb_RS.best_params_)\n    print("Tuned XG Boost Parameters: {}".format(xgb_RS.best_params_), "for",k)\n    print("_" * 100)'

# %%
param_xgb = [{'min_child_weight': 5, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.2, 'colsample_bytree': 0.4, 'scale_pos_weight': 3},
             {'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.2, 'gamma': 0.1, 'colsample_bytree': 0.4},
             {'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.05, 'gamma': 0.4, 'colsample_bytree': 0.4}]

'''
param_xgb = [{'scale_pos_weight': 7, 'min_child_weight': 7, 'max_depth': 3, 'learning_rate': 0.1, 'gamma': 0.4, 'colsample_bytree': 0.4},
             {'scale_pos_weight': 5, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.2, 'gamma': 0.0, 'colsample_bytree': 0.3},
             {'scale_pos_weight': 3, 'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.2, 'gamma': 0.0, 'colsample_bytree': 0.4}]
'''

index = [i for i in range(len(param_xgb))]

# %%
for i,j,k,l in zip(xtrain_data,ytrain_data,name,index):
    print('Data is ',k,' And with hyper parameter ',param_xgb[l])
    model_eval(XGBClassifier(**param_xgb[l],random_state=100), i,j,X_test,y_test)
    print("_" * 60)
# Out:
# Data is  Normal Sampling  And with hyper parameter  {'min_child_weight': 5, 'max_depth': 4, 'learning_rate': 0.1, 'gamma': 0.2, 'colsample_bytree': 0.4, 'scale_pos_weight': 3}
# Overall Train Accuracy 0.7964761904761904
# Train AUC Score 0.8185123005805989
# Overall Test Accuracy 0.7895555555555556
# Test AUC Score 0.7853493811035377
# Classification Report of Test
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      7009
#            1       0.52      0.59      0.55      1991
#
#     accuracy                           0.79      9000
#    macro avg       0.70      0.72      0.71      9000
# weighted avg       0.80      0.79      0.79      9000
#
# K-Fold scores: 0.709 (+/- 0.00007)
# ____________________________________________________________
# Data is  Over Sampling  And with hyper parameter  {'min_child_weight': 1, 'max_depth': 15, 'learning_rate': 0.2, 'gamma': 0.1, 'colsample_bytree': 0.4}
# ...

# %%
import mlflow
mlflow.set_experiment("First Experiment")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

with mlflow.start_run(run_name="Logistic Regression Model"):
    mlflow.log_params(param_lr)
    mlflow.log_metrics({
        'accuracy': LR_report['accuracy'],
        'precision': LR_report['macro avg']['precision'],
        'f1-score': LR_report['macro avg']['f1-score'],
        'recall_0': LR_report['0']['recall'],
        'recall_1': LR_report['1']['recall']
    })
    mlflow.sklearn.log_model(LR, "LR model")
# Out:
# 2026/06/21 18:41:25 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/21 18:41:25 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run Logistic Regression Model at: http://127.0.0.1:5000/#/experiments/1/runs/84ec2181fcd646b8a6bc1cc99d3dd614
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
mlflow.set_experiment("Second Experiment")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")


for i,j,k,l in zip(XGB_reports,XGB_models,name,index):
    model_name = f"XGB Model - {k}"
    model = j
    report = i
    parameters = param_xgb[l]
    
    with mlflow.start_run(run_name=model_name):
        mlflow.log_params(parameters)
        mlflow.log_metrics({
            'accuracy': report['accuracy'],
            'precision': report['macro avg']['precision'],
            'f1-score': report['macro avg']['f1-score'],
            'recall_0': report['0']['recall'],
            'recall_1': report['1']['recall']
        })
        
        mlflow.xgboost.log_model(model, model_name)
# Out:
# 2026/06/21 19:31:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/21 19:31:47 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run XGB Model - Normal Sampling at: http://127.0.0.1:5000/#/experiments/2/runs/aa1fc193a84c4fb3b1622dd8369eceba
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 2026/06/21 19:31:52 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run XGB Model - Over Sampling at: http://127.0.0.1:5000/#/experiments/2/runs/ec4cb376ff6b48418e684fd8a4ba74ef
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# 🏃 View run XGB Model - SMOTE at: http://127.0.0.1:5000/#/experiments/2/runs/bafbba3afa4c4390b888b083a9a652e8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %%
print('All models have been logged to MLflow successfully.')
# Out:
# All models have been logged to MLflow successfully.

# %%
import shap

explainer = shap.TreeExplainer(XGB_models[0])


shap_values = explainer.shap_values(X_test)
sample_index = 3
sample_prediction = XGB_models[0].predict(X_test.iloc[[sample_index]])
actual_label = y_test.iloc[sample_index]

print(actual_label, sample_prediction)

plt.figure(figsize=(10,6))
shap.waterfall_plot(shap.Explanation(values=shap_values[sample_index],
                                     base_values=explainer.expected_value,
                                     data=X_test.iloc[sample_index],
                                        feature_names=X_test.columns.tolist()),
                    max_display=10,
                    show=False)
plt.tight_layout()
plt.show()
# Out:
# 0 [0]

# %%
shap.summary_plot(shap_values, X_test, feature_names=X_test.columns.tolist(), max_display=15, show=False, plot_type='bar')
plt.tight_layout()
plt.show()

# %%
feature_importance = XGB_models[0].feature_importances_
feature_importance_df = pd.DataFrame({
    'Feature': X_test.columns,
    'Importance': feature_importance
}).sort_values(by='Importance', ascending=False)
print(feature_importance_df)
# Out:
#         Feature  Importance
# 3         PAY_2    0.263666
# 2         PAY_1    0.169226
# 4         PAY_3    0.141081
# 6         PAY_5    0.097410
# 5         PAY_4    0.060354
# 7         PAY_6    0.033259
# 14     PAY_AMT1    0.017217
# 8     BILL_AMT1    0.016229
# 15     PAY_AMT2    0.016205
# 16     PAY_AMT3    0.014921
# 0     LIMIT_BAL    0.013900
# 17     PAY_AMT4    0.012835
# 25  EDUCATION_4    0.012470
# 19     PAY_AMT6    0.011287
# 18     PAY_AMT5    0.010280
# 10    BILL_AMT3    0.009905
# 9     BILL_AMT2    0.009842
# 12    BILL_AMT5    0.009349
# 22  EDUCATION_1    0.009335
# 21        SEX_2    0.009150
# 24  EDUCATION_3    0.008554
# 20        SEX_1    0.008421
# 11    BILL_AMT4    0.007809
# 28   MARRIAGE_3    0.006931
# 27   MARRIAGE_2    0.006705
# 13    BILL_AMT6    0.006389
# 26   MARRIAGE_1    0.006283
# 1           AGE    0.006127
# 23  EDUCATION_2    0.004856

# %%
def KS_statistic(y_true, y_pred_prob):
    from sklearn.metrics import roc_curve
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
    ks_statistic = max(tpr - fpr)
    return ks_statistic

def KS_stat(y_true, y_pred_prob):
    import scipy.stats as stats
    # Split the probabilities based on the true class
    prob_positive = y_pred_prob[y_true == 1]
    prob_negative = y_pred_prob[y_true == 0]
    scipy_ks_statistic = stats.ks_2samp(prob_positive, prob_negative).statistic
    return scipy_ks_statistic

ks_val_1 = KS_statistic(y_test, XGB_models[0].predict_proba(X_test)[:,1])
print(f"KS Statistic: {ks_val_1}")
ks_val_2 = KS_stat(y_test, XGB_models[0].predict_proba(X_test)[:,1])
print(f"KS Statistic (scipy): {ks_val_2}")

def gini_coefficient(y_true, y_pred_prob):
    from sklearn.metrics import roc_auc_score
    auc = roc_auc_score(y_true, y_pred_prob)
    gini = 2 * auc - 1
    return gini
gini_val = gini_coefficient(y_test, XGB_models[0].predict_proba(X_test)[:,1])
print(f"Gini Coefficient: {gini_val}")
# Out:
# KS Statistic: 0.43980233779930933
# KS Statistic (scipy): 0.43980233779930933
# Gini Coefficient: 0.5647519702550765
